# %%
from keras.preprocessing.sequence import TimeseriesGenerator

sequence_length=24

# Create time series generators for training and testing
train_data_gen = TimeseriesGenerator(X_train.values, y_train.values, length=sequence_length, batch_size=32)
test_data_gen = TimeseriesGenerator(X_test.values, y_test.values, length=sequence_length, batch_size=32)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Dense, Concatenate
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Flatten, Conv1D, MaxPooling1D, BatchNormalization
from tensorflow.keras.layers import GRU
from scipy.optimize import differential_evolution
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, BatchNormalization, Dropout, LSTM, Dense, Flatten
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
import numpy as np

def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = tf.abs(error) < delta
    small_error_loss = 0.5 * tf.square(error)
    large_error_loss = delta * (tf.abs(error) - 0.5 * delta)
    return tf.where(is_small_error, small_error_loss, large_error_loss)

class MultiHeadAttentionLayer(Layer):
    def __init__(self, num_heads, key_dim, **kwargs):
        super(MultiHeadAttentionLayer, self).__init__(**kwargs)
        self.num_heads = num_heads
        self.key_dim = key_dim
        self.head_dim = key_dim // num_heads

        # Query, Key, and Value Projections
        self.query_projection = Dense(key_dim)
        self.key_projection = Dense(key_dim)
        self.value_projection = Dense(key_dim)

        # Scaled Dot-Product Attention
        self.attention = tf.keras.layers.Attention(use_scale=True)

        # Linear Transformation
        self.output_projection = Dense(key_dim)

    def call(self, inputs):
        # Split inputs into query, key, and value
        query = self.query_projection(inputs)
        key = self.key_projection(inputs)
        value = self.value_projection(inputs)

        # Determine the number of padding elements needed
        padding_elements = self.num_heads - tf.shape(query)[-1] % self.num_heads
        padding = tf.zeros((tf.shape(query)[0], padding_elements))

        # Pad the query tensor
        query = tf.concat([query, tf.expand_dims(padding, axis=-1)], axis=-1)

        # Split into multiple heads
        query_heads = tf.concat(tf.split(query, self.num_heads, axis=-1), axis=0)
        key_heads = tf.concat(tf.split(key, self.num_heads, axis=-1), axis=0)
        value_heads = tf.concat(tf.split(value, self.num_heads, axis=-1), axis=0)

        # Scaled Dot-Product Attention
        attention_output = self.attention([query_heads, key_heads, value_heads])

        # Concatenate heads
        attention_output = tf.concat(tf.split(attention_output, self.num_heads, axis=0), axis=-1)

        # Linear Transformation
        output = self.output_projection(attention_output)

        return output



class TabularLSTMGRUModel:
    def __init__(self, input_shape, lstm_units=[64, 32], gru_units=[64, 32], output_units=1, num_heads=8):
        self.input_shape = input_shape
        self.lstm_units = lstm_units
        self.gru_units = gru_units
        self.output_units = output_units
        self.num_heads = num_heads
        self.model = self.build_model()

    def build_model(self):
        model = tf.keras.Sequential()

        # Convolutional layers
        model.add(Conv1D(filters=256, kernel_size=2, activation='relu', input_shape=self.input_shape))
        model.add(MaxPooling1D(pool_size=2))
        model.add(BatchNormalization())

        model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
        model.add(MaxPooling1D(pool_size=2))
        model.add(BatchNormalization())

        #model.add(MultiHeadAttentionLayer(num_heads=self.num_heads, key_dim=self.lstm_units[-1]))

        model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
        model.add(MaxPooling1D(pool_size=2))
        model.add(BatchNormalization())

        # Multi-Head Attention layer
        #model.add(MultiHeadAttentionLayer(num_heads=self.num_heads, key_dim=self.lstm_units[-1]))

        # GRU layers
        for units in self.gru_units:
            model.add(GRU(units, return_sequences=True, activation='relu'))

        model.add(Flatten())
        model.add(Dense(self.output_units))

        return model

    def compile(self, learning_rate=0.001):
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        self.model.compile(loss=huber_loss, optimizer=optimizer)

    def fit(self, train_data_gen, epochs=10):
        self.model.fit(train_data_gen, epochs=epochs)

    def evaluate(self, test_data_gen):
        return self.model.evaluate(test_data_gen)

    def predict(self, data_gen):
        return self.model.predict(data_gen)

    def summary(self):
        return self.model.summary()

def fitness_function(hyperparameters):
    kernel_number = int(hyperparameters[0])
    activation_function = hyperparameters[1]
    epochs = int(hyperparameters[2])
    learning_rate = hyperparameters[3]

    # Set the hyperparameters in your model
    lstm_gru_model = TabularLSTMGRUModel(
        input_shape,
        lstm_units=hyperparameters[4:len(lstm_units) + 4],
        gru_units=hyperparameters[len(lstm_units) + 4:],
        output_units=1,
        num_heads=8
    )

    # Compile the model with specific learning rate
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    lstm_gru_model.model.compile(loss=huber_loss, optimizer=optimizer)

    # Train the model
    lstm_gru_model.fit(train_data_gen, epochs=epochs)

    # Evaluate and return the fitness score (accuracy, F1-score, etc.)
    fitness_score = lstm_gru_model.evaluate(test_data_gen)

    return fitness_score

def PSO_optimization(num_particles, max_iterations, w, c1, c2, hyperparameter_bounds):
    # PSO initialization
    particles = np.random.uniform(low=hyperparameter_bounds[:, 0], high=hyperparameter_bounds[:, 1], size=(num_particles, len(hyperparameter_bounds)))
    velocities = np.random.rand(num_particles, len(hyperparameter_bounds))
    pbest = particles.copy()
    pbest_values = np.apply_along_axis(fitness_function, 1, particles)
    gbest_index = np.argmax(pbest_values)
    gbest = pbest[gbest_index].copy()
    gbest_value = pbest_values[gbest_index]

    # PSO main loop
    for iteration in range(max_iterations):
        for i in range(num_particles):
            r1, r2 = np.random.rand(), np.random.rand()
            cognitive = c1 * r1 * (pbest[i] - particles[i])
            social = c2 * r2 * (gbest - particles[i])
            velocities[i] = w * velocities[i] + cognitive + social
            particles[i] += velocities[i]
            particles[i] = np.clip(particles[i], hyperparameter_bounds[:, 0], hyperparameter_bounds[:, 1])

            # Update personal best
            fitness_i = fitness_function(particles[i])
            if fitness_i > pbest_values[i]:
                pbest[i] = particles[i].copy()
                pbest_values[i] = fitness_i

            # Update global best
            if fitness_i > gbest_value:
                gbest = particles[i].copy()
                gbest_value = fitness_i

    return gbest

# Assuming you have the input_shape and train_data_gen defined
input_shape = (24, 11)
lstm_units = [64, 32, 16, 8]
gru_units = [64, 32, 16, 8]  # Define the units for each GRU layer

# Define hyperparameter bounds
activation_functions = ['relu', 'tanh']
activation_function_mapping = {act_func: i for i, act_func in enumerate(activation_functions)}

hyperparameter_bounds = np.array([
    [3, 5],  # Kernel number
    [0, len(activation_functions) - 1],  # Activation function (mapped to integers)
    [50, 100],  # Epochs
    [0.0001, 0.001],  # Learning rate
    [16, 8],  # LSTM units
    [64, 32],  # GRU units
])

# Run PSO optimization
optimal_hyperparameters = PSO_optimization(
    num_particles=10,
    max_iterations=50,
    w=0.5,
    c1=1.5,
    c2=1.5,
    hyperparameter_bounds=hyperparameter_bounds
)

# Extract optimal hyperparameters
optimal_kernel_number = int(optimal_hyperparameters[0])
optimal_activation_function_index = int(optimal_hyperparameters[1])
optimal_activation_function = activation_functions[optimal_activation_function_index]
optimal_epochs = int(optimal_hyperparameters[2])
optimal_learning_rate = optimal_hyperparameters[3]
optimal_lstm_units = lstm_units
optimal_gru_units = lstm_units

# Use these optimal hyperparameters to train the final model
lstm_gru_model_optimized = TabularLSTMGRUModel(
    input_shape,
    lstm_units=optimal_lstm_units,
    gru_units=optimal_gru_units,
    output_units=1,
    num_heads=8
)

# Compile the model with the optimal learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=optimal_learning_rate)
lstm_gru_model_optimized.model.compile(loss=huber_loss, optimizer=optimizer)

# Train the final model with optimal hyperparameters
lstm_gru_model_optimized.fit(train_data_gen, epochs=optimal_epochs)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 54/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0097
# Epoch 55/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0078
# Epoch 56/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0091
# Epoch 57/68
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0115
# Epoch 58/68
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0071
# Epoch 59/68
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0047
# Epoch 60/68
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0041
# Epoch 61/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0039
# Epoch 62/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0030
# Epoch 63/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0024
# Epoch 64/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0022
# Epoch 65/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 66/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0017
# Epoch 67/68
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0020
# Epoch 68/68
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0030
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0397
# Epoch 1/92
# 45/45 [==============================] - 4s 21ms/step - loss: 0.4264
# Epoch 2/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.2183
# Epoch 3/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1175
# Epoch 4/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0688
# Epoch 5/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0458
# Epoch 6/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0284
# Epoch 7/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0177
# Epoch 8/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0159
# Epoch 9/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0126
# Epoch 10/92
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0096
# Epoch 11/92
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0082
# Epoch 12/92
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0083
# Epoch 13/92
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0076
# Epoch 14/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0078
# Epoch 15/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0075
# Epoch 16/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0095
# Epoch 17/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0093
# Epoch 18/92
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0091
# Epoch 19/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0115
# Epoch 20/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0113
# Epoch 21/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0124
# Epoch 22/92
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0117
# Epoch 23/92
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0096
# Epoch 24/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0084
# Epoch 25/92
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0073
# Epoch 26/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0062
# Epoch 27/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 28/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0035
# Epoch 29/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0030
# Epoch 30/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0038
# Epoch 31/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0040
# Epoch 32/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0049
# Epoch 33/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0063
# Epoch 34/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0073
# Epoch 35/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0088
# Epoch 36/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0083
# Epoch 37/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0074
# Epoch 38/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0055
# Epoch 39/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0056
# Epoch 40/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0050
# Epoch 41/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0037
# Epoch 42/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0035
# Epoch 43/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0033
# Epoch 44/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0032
# Epoch 45/92
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0030
# Epoch 46/92
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0037
# Epoch 47/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0050
# Epoch 48/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0063
# Epoch 49/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0075
# Epoch 50/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0067
# Epoch 51/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0070
# Epoch 52/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0061
# Epoch 53/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0066
# Epoch 54/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0060
# Epoch 55/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 56/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0034
# Epoch 57/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0031
# Epoch 58/92
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0029
# Epoch 59/92
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0030
# Epoch 60/92
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0027
# Epoch 61/92
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0023
# Epoch 62/92
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0020
# Epoch 63/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 64/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0020
# Epoch 65/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0023
# Epoch 66/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0031
# Epoch 67/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0037
# Epoch 68/92
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0034
# Epoch 69/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0037
# Epoch 70/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0031
# Epoch 71/92
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0040
# Epoch 72/92
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0053
# Epoch 73/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0044
# Epoch 74/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0044
# Epoch 75/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0052
# Epoch 76/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0036
# Epoch 77/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0027
# Epoch 78/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0028
# Epoch 79/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0024
# Epoch 80/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0028
# Epoch 81/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0028
# Epoch 82/92
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0037
# Epoch 83/92
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0044
# Epoch 84/92
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0052
# Epoch 85/92
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0067
# Epoch 86/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0075
# Epoch 87/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0062
# Epoch 88/92
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 89/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0025
# Epoch 90/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 91/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0016
# Epoch 92/92
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0018
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0228
# Epoch 1/75
# 45/45 [==============================] - 3s 22ms/step - loss: 0.4197
# Epoch 2/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.2560
# Epoch 3/75
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1281
# Epoch 4/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0705
# Epoch 5/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0385
# Epoch 6/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0218
# Epoch 7/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0234
# Epoch 8/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0253
# Epoch 9/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0218
# Epoch 10/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0184
# Epoch 11/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0121
# Epoch 12/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0087
# Epoch 13/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0098
# Epoch 14/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0095
# Epoch 15/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0097
# Epoch 16/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0107
# Epoch 17/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0114
# Epoch 18/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0134
# Epoch 19/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0111
# Epoch 20/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0097
# Epoch 21/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0097
# Epoch 22/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0087
# Epoch 23/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0060
# Epoch 24/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0056
# Epoch 25/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0061
# Epoch 26/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0062
# Epoch 27/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0066
# Epoch 28/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0074
# Epoch 29/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0083
# Epoch 30/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0088
# Epoch 31/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0089
# Epoch 32/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0071
# Epoch 33/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0060
# Epoch 34/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0056
# Epoch 35/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0058
# Epoch 36/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0067
# Epoch 37/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0048
# Epoch 38/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0046
# Epoch 39/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0035
# Epoch 40/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0036
# Epoch 41/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0035
# Epoch 42/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 43/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0065
# Epoch 44/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0073
# Epoch 45/75
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0095
# Epoch 46/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0082
# Epoch 47/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0076
# Epoch 48/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0076
# Epoch 49/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 50/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0035
# Epoch 51/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0033
# Epoch 52/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0032
# Epoch 53/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0036
# Epoch 54/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0050
# Epoch 55/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0060
# Epoch 56/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0077
# Epoch 57/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0078
# Epoch 58/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0057
# Epoch 59/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0053
# Epoch 60/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0037
# Epoch 61/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0031
# Epoch 62/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0032
# Epoch 63/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0032
# Epoch 64/75
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0032
# Epoch 65/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0032
# Epoch 66/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0033
# Epoch 67/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0030
# Epoch 68/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0026
# Epoch 69/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0032
# Epoch 70/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0033
# Epoch 71/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0038
# Epoch 72/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0034
# Epoch 73/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0028
# Epoch 74/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0031
# Epoch 75/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0037
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0277
# Epoch 1/73
# 45/45 [==============================] - 3s 21ms/step - loss: 0.4912
# Epoch 2/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1884
# Epoch 3/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0951
# Epoch 4/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0617
# Epoch 5/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0394
# Epoch 6/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0293
# Epoch 7/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0233
# Epoch 8/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0171
# Epoch 9/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0131
# Epoch 10/73
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0106
# Epoch 11/73
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0095
# Epoch 12/73
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0094
# Epoch 13/73
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0119
# Epoch 14/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0140
# Epoch 15/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0151
# Epoch 16/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0164
# Epoch 17/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0142
# Epoch 18/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0105
# Epoch 19/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0081
# Epoch 20/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0054
# Epoch 21/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0045
# Epoch 22/73
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0038
# Epoch 23/73
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0039
# Epoch 24/73
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0037
# Epoch 25/73
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0054
# Epoch 26/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0063
# Epoch 27/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0071
# Epoch 28/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0093
# Epoch 29/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0095
# Epoch 30/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0082
# Epoch 31/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0104
# Epoch 32/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0096
# Epoch 33/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0078
# Epoch 34/73
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0060
# Epoch 35/73
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0064
# Epoch 36/73
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0061
# Epoch 37/73
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0065
# Epoch 38/73
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0055
# Epoch 39/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0042
# Epoch 40/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0045
# Epoch 41/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0052
# Epoch 42/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0060
# Epoch 43/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0049
# Epoch 44/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0034
# Epoch 45/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0032
# Epoch 46/73
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0039
# Epoch 47/73
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0040
# Epoch 48/73
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0052
# Epoch 49/73
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0061
# Epoch 50/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 51/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0039
# Epoch 52/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 53/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0060
# Epoch 54/73
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0074
# Epoch 55/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0076
# Epoch 56/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0055
# Epoch 57/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0050
# Epoch 58/73
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0046
# Epoch 59/73
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0043
# Epoch 60/73
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0036
# Epoch 61/73
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0027
# Epoch 62/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0022
# Epoch 63/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 64/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 65/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0037
# Epoch 66/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0055
# Epoch 67/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0059
# Epoch 68/73
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0070
# Epoch 69/73
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0067
# Epoch 70/73
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0057
# Epoch 71/73
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0041
# Epoch 72/73
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0028
# Epoch 73/73
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0024
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0312
# Epoch 1/83
# 45/45 [==============================] - 3s 17ms/step - loss: 0.5819
# Epoch 2/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3010
# Epoch 3/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1956
# Epoch 4/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1087
# Epoch 5/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0821
# Epoch 6/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0507
# Epoch 7/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0413
# Epoch 8/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0265
# Epoch 9/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0178
# Epoch 10/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0171
# Epoch 11/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0143
# Epoch 12/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0118
# Epoch 13/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0122
# Epoch 14/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0114
# Epoch 15/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0143
# Epoch 16/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0179
# Epoch 17/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0200
# Epoch 18/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0175
# Epoch 19/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0185
# Epoch 20/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0156
# Epoch 21/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0116
# Epoch 22/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0102
# Epoch 23/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0104
# Epoch 24/83
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0098
# Epoch 25/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0078
# Epoch 26/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0062
# Epoch 27/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0058
# Epoch 28/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0055
# Epoch 29/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0052
# Epoch 30/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0055
# Epoch 31/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0051
# Epoch 32/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0064
# Epoch 33/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0092
# Epoch 34/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0105
# Epoch 35/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0090
# Epoch 36/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0120
# Epoch 37/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0106
# Epoch 38/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0084
# Epoch 39/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0097
# Epoch 40/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0100
# Epoch 41/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0098
# Epoch 42/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0089
# Epoch 43/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0087
# Epoch 44/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0082
# Epoch 45/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0061
# Epoch 46/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 47/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0034
# Epoch 48/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0034
# Epoch 49/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0033
# Epoch 50/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0056
# Epoch 51/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0070
# Epoch 52/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0079
# Epoch 53/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0087
# Epoch 54/83
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0088
# Epoch 55/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0066
# Epoch 56/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0082
# Epoch 57/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0088
# Epoch 58/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0101
# Epoch 59/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0073
# Epoch 60/83
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 61/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0046
# Epoch 62/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0035
# Epoch 63/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0031
# Epoch 64/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0032
# Epoch 65/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0035
# Epoch 66/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0033
# Epoch 67/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0039
# Epoch 68/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0042
# Epoch 69/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0052
# Epoch 70/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0062
# Epoch 71/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0069
# Epoch 72/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0073
# Epoch 73/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0107
# Epoch 74/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0081
# Epoch 75/83
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0083
# Epoch 76/83
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0056
# Epoch 77/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0038
# Epoch 78/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0029
# Epoch 79/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0023
# Epoch 80/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 81/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0015
# Epoch 82/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0014
# Epoch 83/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0017
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0255
# Epoch 1/75
# 45/45 [==============================] - 3s 22ms/step - loss: 0.4706
# Epoch 2/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.2099
# Epoch 3/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.1222
# Epoch 4/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0843
# Epoch 5/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0659
# Epoch 6/75
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0384
# Epoch 7/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0255
# Epoch 8/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0186
# Epoch 9/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0175
# Epoch 10/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0155
# Epoch 11/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0137
# Epoch 12/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0110
# Epoch 13/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0113
# Epoch 14/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0146
# Epoch 15/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0154
# Epoch 16/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0134
# Epoch 17/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0137
# Epoch 18/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0132
# Epoch 19/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0147
# Epoch 20/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0153
# Epoch 21/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0102
# Epoch 22/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0104
# Epoch 23/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0109
# Epoch 24/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0074
# Epoch 25/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0057
# Epoch 26/75
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0049
# Epoch 27/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0050
# Epoch 28/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0051
# Epoch 29/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0058
# Epoch 30/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0071
# Epoch 31/75
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0080
# Epoch 32/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0110
# Epoch 33/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0114
# Epoch 34/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0113
# Epoch 35/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0087
# Epoch 36/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0085
# Epoch 37/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0079
# Epoch 38/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0064
# Epoch 39/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0055
# Epoch 40/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0050
# Epoch 41/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0075
# Epoch 42/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0067
# Epoch 43/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0062
# Epoch 44/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0062
# Epoch 45/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0085
# Epoch 46/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0079
# Epoch 47/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0066
# Epoch 48/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 49/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0039
# Epoch 50/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0045
# Epoch 51/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0040
# Epoch 52/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0038
# Epoch 53/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0032
# Epoch 54/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0037
# Epoch 55/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0032
# Epoch 56/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0032
# Epoch 57/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0050
# Epoch 58/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0047
# Epoch 59/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 60/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0044
# Epoch 61/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0045
# Epoch 62/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0053
# Epoch 63/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0047
# Epoch 64/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 65/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0053
# Epoch 66/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0053
# Epoch 67/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0049
# Epoch 68/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0046
# Epoch 69/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0054
# Epoch 70/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0073
# Epoch 71/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0072
# Epoch 72/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0065
# Epoch 73/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 74/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0031
# Epoch 75/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0023
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0359
# Epoch 1/60
# 45/45 [==============================] - 3s 22ms/step - loss: 0.4601
# Epoch 2/60
# 45/45 [==============================] - 1s 23ms/step - loss: 0.2277
# Epoch 3/60
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1079
# Epoch 4/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0759
# Epoch 5/60
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0527
# Epoch 6/60
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0307
# Epoch 7/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0286
# Epoch 8/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0221
# Epoch 9/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0254
# Epoch 10/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0212
# Epoch 11/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0204
# Epoch 12/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0143
# Epoch 13/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0115
# Epoch 14/60
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0080
# Epoch 15/60
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0070
# Epoch 16/60
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0073
# Epoch 17/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0077
# Epoch 18/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0084
# Epoch 19/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0114
# Epoch 20/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0140
# Epoch 21/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0110
# Epoch 22/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0096
# Epoch 23/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0094
# Epoch 24/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0114
# Epoch 25/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0088
# Epoch 26/60
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0073
# Epoch 27/60
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0061
# Epoch 28/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0057
# Epoch 29/60
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0059
# Epoch 30/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0069
# Epoch 31/60
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0078
# Epoch 32/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0082
# Epoch 33/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0080
# Epoch 34/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0068
# Epoch 35/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0064
# Epoch 36/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0072
# Epoch 37/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0052
# Epoch 38/60
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0045
# Epoch 39/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0036
# Epoch 40/60
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0030
# Epoch 41/60
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0042
# Epoch 42/60
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0042
# Epoch 43/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0052
# Epoch 44/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0058
# Epoch 45/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0064
# Epoch 46/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0062
# Epoch 47/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0053
# Epoch 48/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0052
# Epoch 49/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0041
# Epoch 50/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0038
# Epoch 51/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0051
# Epoch 52/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0060
# Epoch 53/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0083
# Epoch 54/60
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0082
# Epoch 55/60
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0060
# Epoch 56/60
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0059
# Epoch 57/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0059
# Epoch 58/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0044
# Epoch 59/60
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0032
# Epoch 60/60
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0045
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0347
# Epoch 1/50
# 45/45 [==============================] - 3s 17ms/step - loss: 0.4552
# Epoch 2/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.2292
# Epoch 3/50
# 45/45 [==============================] - 1s 22ms/step - loss: 0.1143
# Epoch 4/50
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0775
# Epoch 5/50
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0436
# Epoch 6/50
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0280
# Epoch 7/50
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0266
# Epoch 8/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0196
# Epoch 9/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0147
# Epoch 10/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0130
# Epoch 11/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0100
# Epoch 12/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0105
# Epoch 13/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0101
# Epoch 14/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0101
# Epoch 15/50
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0114
# Epoch 16/50
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0148
# Epoch 17/50
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0141
# Epoch 18/50
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0114
# Epoch 19/50
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0111
# Epoch 20/50
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0094
# Epoch 21/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0091
# Epoch 22/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0087
# Epoch 23/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0091
# Epoch 24/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0078
# Epoch 25/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0072
# Epoch 26/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0066
# Epoch 27/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0056
# Epoch 28/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0044
# Epoch 29/50
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0048
# Epoch 30/50
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0050
# Epoch 31/50
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0070
# Epoch 32/50
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0097
# Epoch 33/50
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0113
# Epoch 34/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0111
# Epoch 35/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0095
# Epoch 36/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0077
# Epoch 37/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0063
# Epoch 38/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0072
# Epoch 39/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0061
# Epoch 40/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0054
# Epoch 41/50
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0046
# Epoch 42/50
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0050
# Epoch 43/50
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0055
# Epoch 44/50
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0059
# Epoch 45/50
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0068
# Epoch 46/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0069
# Epoch 47/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0064
# Epoch 48/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0054
# Epoch 49/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0047
# Epoch 50/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0040
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0340
# Epoch 1/83
# 45/45 [==============================] - 3s 17ms/step - loss: 0.4905
# Epoch 2/83
# 45/45 [==============================] - 1s 24ms/step - loss: 0.2534
# Epoch 3/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.1225
# Epoch 4/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0774
# Epoch 5/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0561
# Epoch 6/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0461
# Epoch 7/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0428
# Epoch 8/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0305
# Epoch 9/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0254
# Epoch 10/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0212
# Epoch 11/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0195
# Epoch 12/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0168
# Epoch 13/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0155
# Epoch 14/83
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0117
# Epoch 15/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0102
# Epoch 16/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0095
# Epoch 17/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0120
# Epoch 18/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0151
# Epoch 19/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0151
# Epoch 20/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0118
# Epoch 21/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0092
# Epoch 22/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0095
# Epoch 23/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0103
# Epoch 24/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0090
# Epoch 25/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0058
# Epoch 26/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0056
# Epoch 27/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0069
# Epoch 28/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0078
# Epoch 29/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0086
# Epoch 30/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0079
# Epoch 31/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0072
# Epoch 32/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0065
# Epoch 33/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0070
# Epoch 34/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0073
# Epoch 35/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0074
# Epoch 36/83
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0099
# Epoch 37/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0137
# Epoch 38/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0117
# Epoch 39/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0090
# Epoch 40/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0078
# Epoch 41/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0066
# Epoch 42/83
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0069
# Epoch 43/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0056
# Epoch 44/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0048
# Epoch 45/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0042
# Epoch 46/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0038
# Epoch 47/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0027
# Epoch 48/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0023
# Epoch 49/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0024
# Epoch 50/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0025
# Epoch 51/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0024
# Epoch 52/83
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0027
# Epoch 53/83
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0039
# Epoch 54/83
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0041
# Epoch 55/83
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0048
# Epoch 56/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0059
# Epoch 57/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0083
# Epoch 58/83
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0093
# Epoch 59/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0093
# Epoch 60/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0088
# Epoch 61/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0078
# Epoch 62/83
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0068
# Epoch 63/83
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0056
# ...
# Epoch 69/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 70/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0049
# Epoch 71/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0057
# Epoch 72/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0057
# Epoch 73/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0055
# Epoch 74/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0044
# Epoch 75/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0042
# Epoch 76/80
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0040
# Epoch 77/80
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0037
# Epoch 78/80
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0038
# Epoch 79/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0041
# Epoch 80/80
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0040
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0287
# Epoch 1/75
# 45/45 [==============================] - 3s 18ms/step - loss: 0.5140
# Epoch 2/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2555
# Epoch 3/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1554
# Epoch 4/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0639
# Epoch 5/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0414
# Epoch 6/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0307
# Epoch 7/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0295
# Epoch 8/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0308
# Epoch 9/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0322
# Epoch 10/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0273
# Epoch 11/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0207
# Epoch 12/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0245
# Epoch 13/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0208
# Epoch 14/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0188
# Epoch 15/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0141
# Epoch 16/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0088
# Epoch 17/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0068
# Epoch 18/75
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0072
# Epoch 19/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0089
# Epoch 20/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0090
# Epoch 21/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0092
# Epoch 22/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0094
# Epoch 23/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0090
# Epoch 24/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0092
# Epoch 25/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0104
# Epoch 26/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0120
# Epoch 27/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0129
# Epoch 28/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0179
# Epoch 29/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0185
# Epoch 30/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0085
# Epoch 31/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0056
# Epoch 32/75
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0044
# Epoch 33/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0032
# Epoch 34/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0022
# Epoch 35/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0020
# Epoch 36/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 37/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0026
# Epoch 38/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0032
# Epoch 39/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0050
# Epoch 40/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0062
# Epoch 41/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0076
# Epoch 42/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0089
# Epoch 43/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0113
# Epoch 44/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0129
# Epoch 45/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0120
# Epoch 46/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0098
# Epoch 47/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0081
# Epoch 48/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0061
# Epoch 49/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0045
# Epoch 50/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0031
# Epoch 51/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0029
# Epoch 52/75
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0025
# Epoch 53/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0021
# Epoch 54/75
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0023
# Epoch 55/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0022
# Epoch 56/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0023
# Epoch 57/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 58/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0028
# Epoch 59/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0043
# Epoch 60/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0062
# Epoch 61/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0062
# Epoch 62/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0069
# Epoch 63/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0064
# Epoch 64/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0052
# Epoch 65/75
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0043
# Epoch 66/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0041
# Epoch 67/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0042
# Epoch 68/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0043
# Epoch 69/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0042
# Epoch 70/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0032
# Epoch 71/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0032
# Epoch 72/75
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0029
# Epoch 73/75
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0030
# Epoch 74/75
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0031
# Epoch 75/75
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0048
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0590
# Epoch 1/76
# 45/45 [==============================] - 3s 17ms/step - loss: 0.5502
# Epoch 2/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.2443
# Epoch 3/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1243
# Epoch 4/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0714
# Epoch 5/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0449
# Epoch 6/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0357
# Epoch 7/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0254
# Epoch 8/76
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0243
# Epoch 9/76
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0232
# Epoch 10/76
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0259
# Epoch 11/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0254
# Epoch 12/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0211
# Epoch 13/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0192
# Epoch 14/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0167
# Epoch 15/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0106
# Epoch 16/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0077
# Epoch 17/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0068
# Epoch 18/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0076
# Epoch 19/76
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0072
# Epoch 20/76
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0074
# Epoch 21/76
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0082
# Epoch 22/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0108
# Epoch 23/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0109
# Epoch 24/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0111
# Epoch 25/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0122
# Epoch 26/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0143
# Epoch 27/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0111
# Epoch 28/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0087
# Epoch 29/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0076
# Epoch 30/76
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0078
# Epoch 31/76
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0066
# Epoch 32/76
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0063
# Epoch 33/76
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0075
# Epoch 34/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0069
# Epoch 35/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0063
# Epoch 36/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0049
# Epoch 37/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0048
# Epoch 38/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0051
# Epoch 39/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 40/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 41/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0057
# Epoch 42/76
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0061
# Epoch 43/76
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0057
# Epoch 44/76
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0058
# Epoch 45/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0054
# Epoch 46/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0057
# Epoch 47/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0059
# Epoch 48/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0076
# Epoch 49/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0087
# Epoch 50/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0094
# Epoch 51/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0084
# Epoch 52/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0076
# Epoch 53/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0061
# Epoch 54/76
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0046
# Epoch 55/76
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0038
# Epoch 56/76
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0045
# Epoch 57/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0046
# Epoch 58/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0049
# Epoch 59/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0059
# Epoch 60/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0051
# Epoch 61/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0047
# Epoch 62/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0043
# Epoch 63/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 64/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 65/76
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0036
# Epoch 66/76
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0028
# Epoch 67/76
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0026
# Epoch 68/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0032
# Epoch 69/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0041
# Epoch 70/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 71/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0050
# Epoch 72/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0050
# Epoch 73/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0050
# Epoch 74/76
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0045
# Epoch 75/76
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0036
# Epoch 76/76
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0050
# 20/20 [==============================] - 1s 7ms/step - loss: 0.0403
# Epoch 1/72
# 45/45 [==============================] - 3s 17ms/step - loss: 0.4655
# Epoch 2/72
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1912
# Epoch 3/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1272
# Epoch 4/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0742
# Epoch 5/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0440
# Epoch 6/72
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0313
# Epoch 7/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0228
# Epoch 8/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0187
# Epoch 9/72
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0184
# Epoch 10/72
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0164
# Epoch 11/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0183
# Epoch 12/72
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0150
# Epoch 13/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0126
# Epoch 14/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0102
# Epoch 15/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0081
# Epoch 16/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0078
# Epoch 17/72
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0074
# Epoch 18/72
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0064
# Epoch 19/72
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0073
# Epoch 20/72
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0087
# Epoch 21/72
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0080
# Epoch 22/72
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0095
# Epoch 23/72
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0129
# Epoch 24/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0151
# Epoch 25/72
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0122
# Epoch 26/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0084
# Epoch 27/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0083
# Epoch 28/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0082
# Epoch 29/72
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0078
# Epoch 30/72
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0078
# Epoch 31/72
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0068
# Epoch 32/72
# 37/45 [=======================>......] - ETA: 0s - loss: 0.0059
